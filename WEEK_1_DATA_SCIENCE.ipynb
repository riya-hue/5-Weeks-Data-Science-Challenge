# %% [markdown]
# WEEK 1

# %% [markdown]
# DAY 1-2: Python Basics for Data Science

# %%
a=10
b=3.14
c="Riya"
d=True

my_list=[1,2,3,4]
my_dict={"name":"Riya","age":20}

print(my_list[2])
print(my_dict["name"])
# Out:
# 3
# Riya

# %% [markdown]
# 2.Loops and Functions

# %%
for num in my_list:
  print(num)

def square(x):
  return x*x

print(square(5))
# Out:
# 1
# 2
# 3
# 4
# 25

# %% [markdown]
# 3.Numpy for Arrays

# %%
import numpy as np

arr=np.array([1,2,3,4])
print("Mean",np.mean(arr))
print("Standard Deviation",np.std(arr))
# Out:
# Mean 2.5
# Standard Deviation 1.118033988749895

# %% [markdown]
# 🔹 DAY 3-4: Pandas + Matplotlib + Seaborn

# %% [markdown]
# ✅ 4. Working with Pandas

# %%
import pandas as pd

#create dataframe
data={
    'Name':['A','B','C'],#comma is important
    'Marks':[88,76,93]
}
df = pd.DataFrame(data)
print(df)

# Describe statistics
print(df.describe())
# Out:
#   Name  Marks
# 0    A     88
# 1    B     76
# 2    C     93
#            Marks
# count   3.000000
# mean   85.666667
# std     8.736895
# min    76.000000
# 25%    82.000000
# 50%    88.000000
# 75%    90.500000
# max    93.000000

# %% [markdown]
# ✅ 5. Matplotlib & Seaborn Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Line plot
plt.plot([1, 2, 3], [4, 5, 1])
plt.title("Line Plot")
plt.show()

# Seaborn bar plot
sns.barplot(x='Name', y='Marks', data=df)
plt.title("Marks of Students")
plt.show()

# %% [markdown]
# 🔹 DAY 5-6: Statistics & Probability

# %% [markdown]
# ✅ 6. Basic Statistics

# %%
data = [10, 20, 30, 30, 40]

# Mean, Median, Mode
from statistics import mean, median, mode

print("Mean:", mean(data))
print("Median:", median(data))
print("Mode:", mode(data))
# Out:
# Mean: 26
# Median: 30
# Mode: 30

# %% [markdown]
# ✅ 7. Probability Distributions

# %%
import scipy.stats as stats

# Normal Distribution: mean=0, std=1
x = np.linspace(-5, 5, 100)
y = stats.norm.pdf(x, 0, 1)

plt.plot(x, y)
plt.title("Normal Distribution")
plt.show()

# %% [markdown]
# 🔹 DAY 7: Practice Task

# %% [markdown]
# ✅ Use the Titanic dataset to explore data:

# %%
import seaborn as sns

# Load Titanic dataset
df = sns.load_dataset('titanic')
print(df.head())

# Plot survival by sex
sns.countplot(x='sex', hue='survived', data=df)
plt.title("Survival by Gender")
plt.show()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
